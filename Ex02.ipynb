# %%
ma_variable_longue=2

# %%
ma_variable_longue+3
# Out:
# 5

# %% [markdown]
# ##test

# %%
# %matplotlib inline
from matplotlib.pylab import *
x=linspace(-2*pi,2*pi,200)
y=linspace(-2*pi,2*pi,200)
xx,yy = meshgrid(x,y)
z = sin(xx**2+yy**2) / (xx**2+yy**2)

# %%
imshow(z)

# %%
h = contour(x,y,z)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-8d82d03d552e> in <module>
# ----> 1 h = contour(x,y,z)
#
# NameError: name 'contour' is not defined
